# %%
isinstance(1, object)
# Out:
# True

# %%
isinstance(1.1, object)
# Out:
# True

# %%
isinstance('my_str', object)
# Out:
# True

# %%
def add(a,b):
  return a+b

# %%
isinstance(add, object)
# Out:
# True

# %%
class Animal:
  pass

# %%
my_animal = Animal()

# %%
isinstance(my_animal, object)
# Out:
# True

# %%
isinstance(my_animal, Animal)
# Out:
# True

# %%
dir(my_animal)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Animal:
  def __init__(self, age):
    self.age = age

# %%
my_animal = Animal(3)

# %%
my_animal.age
# Out:
# 3

# %%
dir(my_animal)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age']

# %%
my_other_animal = Animal(4)
my_other_animal.age
# Out:
# 4

# %%
my_other_animal

# %%
my_animal

# %%
class Animal:
  def __init__(self, age):
    self.age = age

  def __repr__(self):
    return f'Animal(age={self.age})'

  def __str__(self):
    return f"This is an animal that's {self.age} old"

# %%
class Person:
  def __init__(self, first_name, last_name, weight, age):
    self.first_name = first_name
    self.last_name = last_name
    self.weight = weight
    self.age = age

  def __repr__(self):    
    return f'Person(age={self.age})’ 
    
  def __str__(self):
    return f"This person's name is {self.first_name}{self.last_name}, they are {self.age} years old, and weigh {self.weight} lbs.”

  def had_birthday(self):    
    return f"{self.first_name}{self.last_name} just had a birthday and is now {self.age + 1}"
# Out:
#   File "<ipython-input-4-f14f305a3163>", line 2
#     def __init__(self, first_name, last_name, weight, age):
#                ^
# SyntaxError: invalid character in identifier

# %%
my_animal = Animal(3)

# %%
my_animal
# Out:
# Animal(age=3)

# %%
str(my_animal)
# Out:
# "This is an animal that's 3 old"

# %%
class Animal:
  def __init__(self, age):
    self.age = age

  def __repr__(self):
    return f'Animal(age={self.age})'

  def __str__(self):
    return f"This is an animal that's {self.age} old"

  def age_next_year(self):
    return self.age + 1

# %%
my_animal = Animal(5)
my_animal
# Out:
# Animal(age=5)

# %%
my_animal.age_next_year()
# Out:
# 6

# %%
my_animal.age
# Out:
# 5

# %%
class Animal:
  def __init__(self, age):
    self.age = age

  def __repr__(self):
    return f'Animal(age={self.age})'

  def __str__(self):
    return f"This is an animal that's {self.age} old"

  def age_next_year(self):
    return self.age + 1

  def add_one_year(self):
    self.age = self.age + 1

# %%
my_animal = Animal(5)

# %%
my_animal.age
# Out:
# 5

# %%
my_animal.add_one_year()

# %%
my_animal.age
# Out:
# 6

# %%
class Animal:
  def __init__(self, age):
    self.age = age

  def __repr__(self):
    return f'Animal(age={self.age})'

  def __str__(self):
    return f"This is an animal that's {self.age} old"

  def age_next_year(self):
    return self.age + 1

  def add_one_year(self):
    self.age = self.age + 1

  def get_weight(self):
    self.weight = 10

# %%
my_animal = Animal(10)

# %%
my_animal.get_weight()

# %%
my_animal.weight
# Out:
# 10

# %% [markdown]
# # Inheritance

# %%
class Animal:
  def __init__(self, age):
    self.age = age

  def __repr__(self):
    return f'Animal(age={self.age})'

  def __str__(self):
    return f"This is an animal that's {self.age} old"

  def age_next_year(self):
    return self.age + 1

  def add_one_year(self):
    self.age = self.age + 1

# %%
class Dog(Animal):
  num_legs = 4
  def __repr__(self):
    return f'Dog(age={self.age})'

  def __str__(self):
    return f"This is an dog that's {self.age} old"

  def bark(self):
    print('woof-woof')


class Fish(Animal):
    def __repr__(self):
      return f'Fish(age={self.age})'

    def __str__(self):
      return f"This is an fish that's {self.age} old"

    def swim(self):
      print('swimming')

# %%
my_dog = Dog(5)
my_dog
# Out:
# Dog(age=5)

# %%
str(my_dog)
# Out:
# "This is an dog that's 5 old"

# %%
my_fish = Fish(2)
my_fish.swim()
# Out:
# swimming

# %%
my_dog.age_next_year()
# Out:
# 6

# %%
class Dog(Animal):
  num_legs = 4
  def __repr__(self):
    return f'Dog(age={self.age})'

  def __str__(self):
    return f"This is an dog that's {self.age} old"

  def bark(self):
    print('woof-woof')

  def is_puppy(self):
    if self.age <= 1:
      return True
    else:
      return False

# %%
my_dog = Dog(0.5)

# %%
my_dog.is_puppy()
# Out:
# True

# %%
my_dog.add_one_year()

# %%
my_dog.is_puppy()
# Out:
# False

# %%
my_dog.age
# Out:
# 1.5

# %%
my_dog.num_legs
# Out:
# 4

# %%
Dog.num_legs
# Out:
# 4

# %%
import datetime

datetime.datetime.now()
# Out:
# datetime.datetime(2019, 11, 1, 3, 3, 25, 685486)

# %%
class Dog(Animal):
  num_legs = 4
  
  def __init__(self, age, weight):
    super().__init__(age)
    self.weight = weight

  def bark(self):
    print('woof-woof')

  def is_puppy(self):
    if self.age <= 1:
      return True
    else:
      return False

  def eat(self):
    self.last_time_fed = datetime.datetime.now()
    self.weight = 1.01*self.weight 

  def get_time_last_fed(self):
    time_sec_since_last_time_fed = (datetime.datetime.now() - self.last_time_fed).total_seconds()
    return time_sec_since_last_time_fed

  def is_hungry(self):
    if self.get_time_last_fed() > 10: # seconds
      return True
    else:
      return False

  def __repr__(self):
    return f'Dog(age={self.age}, weight={self.weight})'

  def __str__(self):
    return f"This is an dog that's {self.age} old"

# %%
my_dog = Dog(age=3, weight=50)
my_dog
# Out:
# Dog(age=3, weight=50)

# %%
my_dog.eat()

# %%
my_dog.get_time_last_fed()
# Out:
# 15.532996

# %%
my_dog.is_hungry()
# Out:
# True

# %%
my_dog.eat()

# %%
my_dog.is_hungry()
# Out:
# True

# %%
class Dog(Animal):
  num_legs = 4
  
  def __init__(self, age, weight):
    super().__init__(age)
    self.weight = weight

  def bark(self):
    print('woof-woof')

  def is_puppy(self):
    if self.age <= 1:
      return True
    else:
      return False

  def eat(self):
    self.last_time_fed = datetime.datetime.now()
    self.weight = 1.01*self.weight 

  def get_time_last_fed(self):
    time_sec_since_last_time_fed = (datetime.datetime.now() - self.last_time_fed).total_seconds()
    return time_sec_since_last_time_fed

  def is_hungry(self):
    if self.get_time_last_fed() > 10: # seconds
      return True
    else:
      return False

  def __repr__(self):
    return f'Dog(age={self.age}, weight={self.weight})'

  def __str__(self):
    return f"This is an dog that's {self.age} old"

  def __eq__(self, other):
    return (self.age == other.age) and (self.weight == other.weight)

  def __lt__(self, other):
    return self.weight < other.weight

# %%
my_dog = Dog(3, 50)
my_other_dog = Dog(3, 51)

# %%
my_dog == my_other_dog
# Out:
# False

# %%
my_dog > my_other_dog
# Out:
# False
